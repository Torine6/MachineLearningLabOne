# %%
import pandas as pd

# %%
irisdf = pd.read_csv('data.csv')

# %%
irisdf.head(5)
# Out:
#      ID Name in English  Name in French      Name in Spanish  \
# 0  1022   South Italian  italien du sud  napolitano-calabrés
# 1  1023        Sicilian        sicilien            siciliano
# 2   383       Low Saxon       bas-saxon           bajo sajón
# 3   335      Belarusian      biélorusse           bielorruso
# 4   382         Lombard         lombard             lombardo
#
#                                            Countries  \
# 0                                              Italy
# 1                                              Italy
# 2  Germany, Denmark, Netherlands, Poland, Russian...
# 3  Belarus, Latvia, Lithuania, Poland, Russian Fe...
# 4                                 Italy, Switzerland
#
#           Country codes alpha 3  \
# 0                           ITA
# 1                           ITA
# 2       DEU, DNK, NLD, POL, RUS
# 3  BRB, LVA, LTU, POL, RUS, UKR
# 4                      ITA, CHE
#
# ...

# %%
irisdf.tail(5)
# Out:
#         ID    Name in English     Name in French    Name in Spanish  \
# 2717  1972           Yonaguni           yonaguni           yonaguni
# 2718  2018             Yucuna             yucuna             yucuna
# 2719  2015  Yurutí (Colombia)  yurutí (Colombie)  yurutí (Colombia)
# 2720  2716          Zangskari          zangskari          zangskari
# 2721  2177            Zidgali            zidgali            zidgali
#
#             Countries Country codes alpha 3 ISO639-3 codes  \
# 2717            Japan                   JPN            yoi
# 2718         Colombia                   COL            ycn
# 2719         Colombia                   COL            yui
# 2720  India, Pakistan              IND, PAK            zau
# 2721             Oman                   OMN            NaN
#
#      Degree of endangerment       Alternate names Name in the language  \
# 2717    Severely endangered                   NaN                  NaN
# ...

# %%
irisdf['Countries']
# Out:
# 0                                                   Italy
# 1                                                   Italy
# 2       Germany, Denmark, Netherlands, Poland, Russian...
# 3       Belarus, Latvia, Lithuania, Poland, Russian Fe...
# 4                                      Italy, Switzerland
#                               ...
# 2717                                                Japan
# 2718                                             Colombia
# 2719                                             Colombia
# 2720                                      India, Pakistan
# 2721                                                 Oman
# Name: Countries, Length: 2722, dtype: object

# %%
irisdf["Countries"].count()
# Out:
# 2721

# %%
irisdf["Countries"].value_counts()
# Out:
# United States of America               216
# Brazil                                 186
# India                                  163
# Indonesia                              149
# Mexico                                 143
#                                       ...
# Slovenia                                 1
# Bulgaria                                 1
# Netherlands                              1
# Finland, Norway, Russian Federation      1
# Burkina Faso                             1
# Name: Countries, Length: 252, dtype: int64

# %%
irisdf['Degree of endangerment']
# Out:
# 0                  Vulnerable
# 1                  Vulnerable
# 2                  Vulnerable
# 3                  Vulnerable
# 4       Definitely endangered
#                 ...
# 2717      Severely endangered
# 2718    Definitely endangered
# 2719    Definitely endangered
# 2720    Definitely endangered
# 2721    Critically endangered
# Name: Degree of endangerment, Length: 2722, dtype: object

# %%
irisdf['Degree of endangerment'].value_counts()
# Out:
# Definitely endangered    680
# Vulnerable               628
# Critically endangered    607
# Severely endangered      554
# Extinct                  253
# Name: Degree of endangerment, dtype: int64

# %%
irisdf['Degree of endangerment'].value_counts().plot(kind="bar")
# Out:
# Matplotlib is building the font cache; this may take a moment.
# <AxesSubplot:>

# %% [raw]
# irisdf['Languages'] = irisdf.groupby('Degree of endangerment')
# x_Degree_of_endangerment=('critically endagered'
#                        'Severely endagered')
#
# y_counts= irisdf['Degree of endangerment'].value_counts().plot(kind="bar")
#
# plt.figure(figsize=(10,6))
# plt.bar(x,y)
# plt.bar(x_Degree_of_endangerment, y_counts)
# plt.xlabel("Degreee of endagerment")
# plt.ylabel('Number of languages')
#
# plt.title("Number of languages by degree of endagerment")
#
# plt.show()

# %%
eastAfricaLanguages = ((irisdf.Countries == "Kenya") | 
                       (irisdf.Countries == "Ethiopia")
                      )

# %%
irisdf[eastAfricaLanguages]
# Out:
#         ID             Name in English Name in French  \
# 195   1686                         Yem            yem
# 421   1684                        Oyda           oyda
# 436   1681                       Kwama          kwama
# 572   1685                     Ts'amay      ts'amakko
# 581     88                     Argobba        argobba
# 615     91                       Burji          burji
# 631   1677                       Chara          chara
# 641   1676                       Bussa          bussa
# 649     83                       Dimme           dime
# 699   1671                    Bambassi       bambassi
# 759   1673                      Arbore         arbore
# 805     85                        Nayi           nayi
# 825   1679                       Mursi          mursi
# 836     99                        Boni           boni
# 847     77                        Hozo           hozo
# 951     81                       Bayso          bayso
# ...

# %%
eastAfricaLanguagesOne= irisdf.Countries.isin(['Kenya','Ethiopia','Tanzania','Uganda','Rwanda','Burundi','South Sudan','Somalia'])

# %%
irisdf[eastAfricaLanguagesOne]
# Out:
#         ID             Name in English Name in French  \
# 195   1686                         Yem            yem
# 421   1684                        Oyda           oyda
# 424    109                        Amba           amba
# 436   1681                       Kwama          kwama
# 572   1685                     Ts'amay      ts'amakko
# 581     88                     Argobba        argobba
# 615     91                       Burji          burji
# 631   1677                       Chara          chara
# 641   1676                       Bussa          bussa
# 649     83                       Dimme           dime
# 699   1671                    Bambassi       bambassi
# 759   1673                      Arbore         arbore
# 805     85                        Nayi           nayi
# 825   1679                       Mursi          mursi
# 836     99                        Boni           boni
# 847     77                        Hozo           hozo
# ...

# %%
irisdf[eastAfricaLanguagesOne].value_counts()
# Out:
# Series([], dtype: int64)

# %%
irisdf[eastAfricaLanguagesOne].loc[:,['Degree of endangerment']].value_counts()
# Out:
# Degree of endangerment
# Extinct                   12
# Vulnerable                10
# Critically endangered      9
# Definitely endangered      8
# Severely endangered        5
# dtype: int64

# %%
irisdf[eastAfricaLanguagesOne].loc[:,['Degree of endangerment']].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='Degree of endangerment'>

# %%
checkAngola = (irisdf.Countries.isin(['Angola']))

# %%
irisdf[checkAngola]
# Out:
#        ID Name in English Name in French Name in Spanish Countries  \
# 891   127            Bolo           bolo            bolo    Angola
# 2385  126            Kede           kede            kede    Angola
# 2402  124           Kwadi          kwadi           kuadí    Angola
# 2403  125           Kwisi          kwisi           kwisi    Angola
#
#      Country codes alpha 3 ISO639-3 codes Degree of endangerment  \
# 891                    ANG            blv  Definitely endangered
# 2385                   ANG            NaN                Extinct
# 2402                   ANG            kwz                Extinct
# 2403                   ANG            NaN                Extinct
#
#      Alternate names Name in the language  Number of speakers  \
# 891              NaN                  NaN              2627.0
# 2385             NaN                  NaN                 0.0
# 2402             NaN                  NaN                 0.0
# ...

# %%
wrongCheckAngola = irisdf[checkAngola].loc[:,['Country codes alpha 3']]

# %%
print(wrongCheckAngola)
# Out:
#      Country codes alpha 3
# 891                    ANG
# 2385                   ANG
# 2402                   ANG
# 2403                   ANG

# %%
wrongCheckAngola.replace("ANG", "AO" ,inplace = True)

# %%
print(wrongCheckAngola)
# Out:
#      Country codes alpha 3
# 891                     AO
# 2385                    AO
# 2402                    AO
# 2403                    AO

# %%
checkAngola = (irisdf.Countries.isin(['Angola']))

# %%
irisdf[checkAngola]
# Out:
#        ID Name in English Name in French Name in Spanish Countries  \
# 891   127            Bolo           bolo            bolo    Angola
# 2385  126            Kede           kede            kede    Angola
# 2402  124           Kwadi          kwadi           kuadí    Angola
# 2403  125           Kwisi          kwisi           kwisi    Angola
#
#      Country codes alpha 3 ISO639-3 codes Degree of endangerment  \
# 891                    ANG            blv  Definitely endangered
# 2385                   ANG            NaN                Extinct
# 2402                   ANG            kwz                Extinct
# 2403                   ANG            NaN                Extinct
#
#      Alternate names Name in the language  Number of speakers  \
# 891              NaN                  NaN              2627.0
# 2385             NaN                  NaN                 0.0
# 2402             NaN                  NaN                 0.0
# ...

# %%
irisdf.replace('ANG','AO', inplace=True)

# %%
checkAngola = (irisdf.Countries.isin(['Angola']))
irisdf[checkAngola]
# Out:
#        ID Name in English Name in French Name in Spanish Countries  \
# 891   127            Bolo           bolo            bolo    Angola
# 2385  126            Kede           kede            kede    Angola
# 2402  124           Kwadi          kwadi           kuadí    Angola
# 2403  125           Kwisi          kwisi           kwisi    Angola
#
#      Country codes alpha 3 ISO639-3 codes Degree of endangerment  \
# 891                     AO            blv  Definitely endangered
# 2385                    AO            NaN                Extinct
# 2402                    AO            kwz                Extinct
# 2403                    AO            NaN                Extinct
#
#      Alternate names Name in the language  Number of speakers  \
# 891              NaN                  NaN              2627.0
# 2385             NaN                  NaN                 0.0
# 2402             NaN                  NaN                 0.0
# ...
